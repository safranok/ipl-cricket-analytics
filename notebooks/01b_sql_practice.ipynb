# %% [markdown]
# # IPL SQL Analysis — Final Assignment
#
# **Notebook:** `01b_sql_practice.ipynb`
#
# This notebook contains the SQL queries required by the IPL SQL Analysis assignment.
# For each command, the query is followed by a short observation explaining what the SQL command demonstrates.
#
# **Workflow:** COMMENT → SQL QUERY → RUN → RESULT → OBSERVATION

# %%
import sqlite3
import pandas as pd

con = sqlite3.connect("../data/raw/ipl.db")

def q(sql):
    return pd.read_sql(sql, con)

# Test the database connection
q("SELECT COUNT(*) AS total_matches FROM matches;")
# Out:
#    total_matches
# 0           1212

# %% [markdown]
# ## Part A — Basic Exploration

# %%
# Command 1 — SELECT and FROM
q("""
SELECT *
FROM teams;
""")

# My observation:
# SELECT * displays all columns and rows from the teams table.
# Out:
#     team_id                    team_name
# 0         1  Royal Challengers Bangalore
# 1         2          Sunrisers Hyderabad
# 2         3               Mumbai Indians
# 3         4       Rising Pune Supergiant
# 4         5                Gujarat Lions
# 5         6        Kolkata Knight Riders
# 6       129          Chennai Super Kings
# 7       134             Rajasthan Royals
# 8       252               Delhi Capitals
# 9       494                 Punjab Kings
# 10      614         Lucknow Super Giants
# 11      615               Gujarat Titans
# 12     1068              Deccan Chargers
# 13     1414         Kochi Tuskers Kerala
# 14     1419                Pune Warriors
# 15     3604      Rising Pune Supergiants

# %%
# Command 2 — LIMIT
q("""
SELECT *
FROM deliveries
LIMIT 10;
""")

# My observation:
# LIMIT restricts the number of rows returned by the query.
# Out:
#    season_id  match_id       batter   bowler  non_striker  over_number  \
# 0       2008    335982   SC Ganguly  P Kumar  BB McCullum            0
# 1       2008    335982  BB McCullum  P Kumar   SC Ganguly            0
# 2       2008    335982  BB McCullum  P Kumar   SC Ganguly            0
# 3       2008    335982  BB McCullum  P Kumar   SC Ganguly            0
# 4       2008    335982  BB McCullum  P Kumar   SC Ganguly            0
# 5       2008    335982  BB McCullum  P Kumar   SC Ganguly            0
# 6       2008    335982  BB McCullum  P Kumar   SC Ganguly            0
# 7       2008    335982  BB McCullum   Z Khan   SC Ganguly            1
# 8       2008    335982  BB McCullum   Z Khan   SC Ganguly            1
# 9       2008    335982  BB McCullum   Z Khan   SC Ganguly            1
#
#    ball_number  batter_runs  extras  total_runs  ... leg_bye_runs bye_runs  \
# 0            0            0       1           1  ...            1        0
# 1            1            0       0           0  ...            0        0
# 2            2            0       1           1  ...            0        0
# 3            3            0       0           0  ...            0        0
# 4            4            0       0           0  ...            0        0
# 5            5            0       0           0  ...            0        0
# 6            6            0       1           1  ...            1        0
# 7            0            0       0           0  ...            0        0
# 8            1            4       0           4  ...            0        0
# 9            2            4       0           4  ...            0        0
#
#   penalty_runs wicket_kind  is_super_over  innings  batting_team_id  \
# 0            0        None              0        1                6
# 1            0        None              0        1                6
# 2            0        None              0        1                6
# 3            0        None              0        1                6
# 4            0        None              0        1                6
# 5            0        None              0        1                6
# 6            0        None              0        1                6
# 7            0        None              0        1                6
# 8            0        None              0        1                6
# 9            0        None              0        1                6
#
#    bowling_team_id           batting_team                 bowling_team
# 0                1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1                1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2                1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3                1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4                1  Kolkata Knight Riders  Royal Challengers Bangalore
# 5                1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6                1  Kolkata Knight Riders  Royal Challengers Bangalore
# 7                1  Kolkata Knight Riders  Royal Challengers Bangalore
# 8                1  Kolkata Knight Riders  Royal Challengers Bangalore
# 9                1  Kolkata Knight Riders  Royal Challengers Bangalore
#
# [10 rows x 32 columns]

# %%
# Command 3 — Selecting Specific Columns
q("""
SELECT match_id, season, match_winner, result
FROM matches;
""")

# My observation:
# SELECT can be used to return only the columns needed for analysis.
# Out:
#       match_id season                 match_winner result
# 0       335982   2008        Kolkata Knight Riders    win
# 1      1082591   2017          Sunrisers Hyderabad    win
# 2      1082592   2017       Rising Pune Supergiant    win
# 3      1082593   2017        Kolkata Knight Riders    win
# 4      1082594   2017                 Punjab Kings    win
# ...        ...    ...                          ...    ...
# 1207   1529282   2026  Royal Challengers Bangalore    win
# 1208   1529283   2026             Rajasthan Royals    win
# 1209   1529284   2026          Sunrisers Hyderabad    win
# 1210   1529285   2026               Gujarat Titans    win
# 1211   1529286   2026               Delhi Capitals    win
#
# [1212 rows x 4 columns]

# %%
# Command 4 — DISTINCT
q("""
SELECT DISTINCT season
FROM matches
ORDER BY season;
""")

# My observation:
# DISTINCT removes duplicate values and shows each season only once.
# Out:
#      season
# 0      2008
# 1      2009
# 2      2010
# 3      2011
# 4      2012
# 5      2013
# 6      2014
# 7      2015
# 8      2016
# 9      2017
# 10     2018
# 11     2019
# 12  2020/21
# 13     2021
# 14     2022
# 15     2023
# 16     2024
# 17     2025
# 18     2026

# %%
# Command 5 — DISTINCT cities
q("""
SELECT DISTINCT city
FROM matches
ORDER BY city;
""")

# My observation:
# DISTINCT shows the unique cities recorded in the matches table.
# Out:
#               city
# 0              NaN
# 1        Abu Dhabi
# 2        Ahmedabad
# 3        Bangalore
# 4        Bengaluru
# 5     Bloemfontein
# 6        Cape Town
# 7        Centurion
# 8       Chandigarh
# 9          Chennai
# 10         Cuttack
# 11           Delhi
# 12      Dharamsala
# 13           Dubai
# 14          Durban
# 15     East London
# 16        Guwahati
# 17       Hyderabad
# 18          Indore
# 19          Jaipur
# 20    Johannesburg
# 21          Kanpur
# 22       Kimberley
# 23           Kochi
# 24         Kolkata
# 25         Lucknow
# 26          Mohali
# 27          Mumbai
# 28          Nagpur
# 29     Navi Mumbai
# 30  New Chandigarh
# 31  Port Elizabeth
# 32            Pune
# 33          Raipur
# 34          Rajkot
# 35          Ranchi
# 36         Sharjah
# 37   Visakhapatnam

# %% [markdown]
# ## Part B — Filtering and Sorting

# %%
# Command 6 — WHERE
q("""
SELECT *
FROM matches
WHERE season = 2019;
""")

# My observation:
# WHERE filters the table so that only matches from the 2019 season are returned.
# Out:
#     match_id  season_id  balls_per_over           city  match_date  \
# 0    1175356       2019               6        Chennai  2019-03-23
# 1    1175357       2019               6        Kolkata  2019-03-24
# 2    1175358       2019               6         Mumbai  2019-03-24
# 3    1175359       2019               6         Jaipur  2019-03-25
# 4    1175360       2019               6          Delhi  2019-03-26
# 5    1175361       2019               6        Kolkata  2019-03-27
# 6    1175362       2019               6      Bengaluru  2019-03-28
# 7    1175363       2019               6      Hyderabad  2019-03-29
# 8    1175364       2019               6     Chandigarh  2019-03-30
# 9    1175365       2019               6          Delhi  2019-03-30
# 10   1175366       2019               6      Hyderabad  2019-03-31
# 11   1175367       2019               6        Chennai  2019-03-31
# 12   1175368       2019               6     Chandigarh  2019-04-01
# 13   1175369       2019               6         Jaipur  2019-04-02
# 14   1175370       2019               6         Mumbai  2019-04-03
# 15   1175371       2019               6          Delhi  2019-04-04
# 16   1175372       2019               6      Bengaluru  2019-04-05
# 17   1178393       2019               6        Chennai  2019-04-06
# 18   1178394       2019               6      Hyderabad  2019-04-06
# 19   1178395       2019               6      Bengaluru  2019-04-07
# 20   1178396       2019               6         Jaipur  2019-04-07
# 21   1178397       2019               6     Chandigarh  2019-04-08
# 22   1178398       2019               6        Chennai  2019-04-09
# 23   1178399       2019               6         Mumbai  2019-04-10
# 24   1178400       2019               6         Jaipur  2019-04-11
# 25   1178401       2019               6        Kolkata  2019-04-12
# 26   1178402       2019               6         Mumbai  2019-04-13
# 27   1178403       2019               6     Chandigarh  2019-04-13
# 28   1178404       2019               6        Kolkata  2019-04-14
# 29   1178405       2019               6      Hyderabad  2019-04-14
# 30   1178406       2019               6         Mumbai  2019-04-15
# 31   1178407       2019               6     Chandigarh  2019-04-16
# 32   1178408       2019               6      Hyderabad  2019-04-17
# 33   1178409       2019               6          Delhi  2019-04-18
# 34   1178410       2019               6        Kolkata  2019-04-19
# 35   1178411       2019               6         Jaipur  2019-04-20
# 36   1178412       2019               6          Delhi  2019-04-20
# 37   1178413       2019               6      Hyderabad  2019-04-21
# 38   1178414       2019               6      Bengaluru  2019-04-21
# 39   1178415       2019               6         Jaipur  2019-04-22
# 40   1178416       2019               6        Chennai  2019-04-23
# 41   1178417       2019               6      Bengaluru  2019-04-24
# 42   1178418       2019               6        Kolkata  2019-04-25
# 43   1178419       2019               6        Chennai  2019-04-26
# 44   1178420       2019               6         Jaipur  2019-04-27
# 45   1178421       2019               6          Delhi  2019-04-28
# 46   1178422       2019               6        Kolkata  2019-04-28
# 47   1178423       2019               6      Hyderabad  2019-04-29
# 48   1178424       2019               6      Bengaluru  2019-04-30
# 49   1178425       2019               6        Chennai  2019-05-01
# 50   1178426       2019               6         Mumbai  2019-05-02
# 51   1178427       2019               6     Chandigarh  2019-05-03
# 52   1178428       2019               6          Delhi  2019-05-04
# 53   1178429       2019               6      Bengaluru  2019-05-04
# 54   1178430       2019               6     Chandigarh  2019-05-05
# 55   1178431       2019               6         Mumbai  2019-05-05
# 56   1181764       2019               6        Chennai  2019-05-07
# 57   1181766       2019               6  Visakhapatnam  2019-05-08
# 58   1181767       2019               6  Visakhapatnam  2019-05-10
# 59   1181768       2019               6      Hyderabad  2019-05-12
#
#                event_name  match_number gender match_type format  ...  \
# 0   Indian Premier League           1.0   male        T20    T20  ...
# 1   Indian Premier League           2.0   male        T20    T20  ...
# 2   Indian Premier League           3.0   male        T20    T20  ...
# 3   Indian Premier League           4.0   male        T20    T20  ...
# 4   Indian Premier League           5.0   male        T20    T20  ...
# 5   Indian Premier League           6.0   male        T20    T20  ...
# 6   Indian Premier League           7.0   male        T20    T20  ...
# 7   Indian Premier League           8.0   male        T20    T20  ...
# 8   Indian Premier League           9.0   male        T20    T20  ...
# 9   Indian Premier League          10.0   male        T20    T20  ...
# 10  Indian Premier League          11.0   male        T20    T20  ...
# 11  Indian Premier League          12.0   male        T20    T20  ...
# 12  Indian Premier League          13.0   male        T20    T20  ...
# 13  Indian Premier League          14.0   male        T20    T20  ...
# 14  Indian Premier League          15.0   male        T20    T20  ...
# 15  Indian Premier League          16.0   male        T20    T20  ...
# 16  Indian Premier League          17.0   male        T20    T20  ...
# 17  Indian Premier League          18.0   male        T20    T20  ...
# 18  Indian Premier League          19.0   male        T20    T20  ...
# 19  Indian Premier League          20.0   male        T20    T20  ...
# 20  Indian Premier League          21.0   male        T20    T20  ...
# 21  Indian Premier League          22.0   male        T20    T20  ...
# 22  Indian Premier League          23.0   male        T20    T20  ...
# 23  Indian Premier League          24.0   male        T20    T20  ...
# 24  Indian Premier League          25.0   male        T20    T20  ...
# 25  Indian Premier League          26.0   male        T20    T20  ...
# 26  Indian Premier League          27.0   male        T20    T20  ...
# 27  Indian Premier League          28.0   male        T20    T20  ...
# 28  Indian Premier League          29.0   male        T20    T20  ...
# 29  Indian Premier League          30.0   male        T20    T20  ...
# 30  Indian Premier League          31.0   male        T20    T20  ...
# 31  Indian Premier League          32.0   male        T20    T20  ...
# 32  Indian Premier League          33.0   male        T20    T20  ...
# 33  Indian Premier League          34.0   male        T20    T20  ...
# 34  Indian Premier League          35.0   male        T20    T20  ...
# 35  Indian Premier League          36.0   male        T20    T20  ...
# 36  Indian Premier League          37.0   male        T20    T20  ...
# 37  Indian Premier League          38.0   male        T20    T20  ...
# 38  Indian Premier League          39.0   male        T20    T20  ...
# 39  Indian Premier League          40.0   male        T20    T20  ...
# 40  Indian Premier League          41.0   male        T20    T20  ...
# 41  Indian Premier League          42.0   male        T20    T20  ...
# 42  Indian Premier League          43.0   male        T20    T20  ...
# 43  Indian Premier League          44.0   male        T20    T20  ...
# 44  Indian Premier League          45.0   male        T20    T20  ...
# 45  Indian Premier League          46.0   male        T20    T20  ...
# 46  Indian Premier League          47.0   male        T20    T20  ...
# 47  Indian Premier League          48.0   male        T20    T20  ...
# 48  Indian Premier League          49.0   male        T20    T20  ...
# 49  Indian Premier League          50.0   male        T20    T20  ...
# 50  Indian Premier League          51.0   male        T20    T20  ...
# 51  Indian Premier League          52.0   male        T20    T20  ...
# 52  Indian Premier League          53.0   male        T20    T20  ...
# 53  Indian Premier League          54.0   male        T20    T20  ...
# 54  Indian Premier League          55.0   male        T20    T20  ...
# 55  Indian Premier League          56.0   male        T20    T20  ...
# 56  Indian Premier League           NaN   male        T20    T20  ...
# 57  Indian Premier League           NaN   male        T20    T20  ...
# 58  Indian Premier League           NaN   male        T20    T20  ...
# 59  Indian Premier League           NaN   male        T20    T20  ...
#
#                    match_winner win_by_runs win_by_wickets     result  \
# 0           Chennai Super Kings         NaN            7.0        win
# 1         Kolkata Knight Riders         NaN            6.0        win
# 2                Delhi Capitals        37.0            NaN        win
# 3                  Punjab Kings        14.0            NaN        win
# 4           Chennai Super Kings         NaN            6.0        win
# 5         Kolkata Knight Riders        28.0            NaN        win
# 6                Mumbai Indians         6.0            NaN        win
# 7           Sunrisers Hyderabad         NaN            5.0        win
# 8                  Punjab Kings         NaN            8.0        win
# 9                Delhi Capitals         NaN            NaN        tie
# 10          Sunrisers Hyderabad       118.0            NaN        win
# 11          Chennai Super Kings         8.0            NaN        win
# 12                 Punjab Kings        14.0            NaN        win
# 13             Rajasthan Royals         NaN            7.0        win
# 14               Mumbai Indians        37.0            NaN        win
# 15          Sunrisers Hyderabad         NaN            5.0        win
# 16        Kolkata Knight Riders         NaN            5.0        win
# 17          Chennai Super Kings        22.0            NaN        win
# 18               Mumbai Indians        40.0            NaN        win
# 19               Delhi Capitals         NaN            4.0        win
# 20        Kolkata Knight Riders         NaN            8.0        win
# 21                 Punjab Kings         NaN            6.0        win
# 22          Chennai Super Kings         NaN            7.0        win
# 23               Mumbai Indians         NaN            3.0        win
# 24          Chennai Super Kings         NaN            4.0        win
# 25               Delhi Capitals         NaN            7.0        win
# 26             Rajasthan Royals         NaN            4.0        win
# 27  Royal Challengers Bangalore         NaN            8.0        win
# 28          Chennai Super Kings         NaN            5.0        win
# 29               Delhi Capitals        39.0            NaN        win
# 30               Mumbai Indians         NaN            5.0        win
# 31                 Punjab Kings        12.0            NaN        win
# 32          Sunrisers Hyderabad         NaN            6.0        win
# 33               Mumbai Indians        40.0            NaN        win
# 34  Royal Challengers Bangalore        10.0            NaN        win
# 35             Rajasthan Royals         NaN            5.0        win
# 36               Delhi Capitals         NaN            5.0        win
# 37          Sunrisers Hyderabad         NaN            9.0        win
# 38  Royal Challengers Bangalore         1.0            NaN        win
# 39               Delhi Capitals         NaN            6.0        win
# 40          Chennai Super Kings         NaN            6.0        win
# 41  Royal Challengers Bangalore        17.0            NaN        win
# 42             Rajasthan Royals         NaN            3.0        win
# 43               Mumbai Indians        46.0            NaN        win
# 44             Rajasthan Royals         NaN            7.0        win
# 45               Delhi Capitals        16.0            NaN        win
# 46        Kolkata Knight Riders        34.0            NaN        win
# 47          Sunrisers Hyderabad        45.0            NaN        win
# 48             Rajasthan Royals         NaN            NaN  no result
# 49          Chennai Super Kings        80.0            NaN        win
# 50          Sunrisers Hyderabad         NaN            NaN        tie
# 51        Kolkata Knight Riders         NaN            7.0        win
# 52               Delhi Capitals         NaN            5.0        win
# 53  Royal Challengers Bangalore         NaN            4.0        win
# 54                 Punjab Kings         NaN            6.0        win
# 55               Mumbai Indians         NaN            9.0        win
# 56               Mumbai Indians         NaN            6.0        win
# 57               Delhi Capitals         NaN            2.0        win
# 58          Chennai Super Kings         NaN            6.0        win
# 59               Mumbai Indians         1.0            NaN        win
#
#     player_of_match team1_id team2_id toss_winner_id match_winner_id  \
# 0   Harbhajan Singh        1      129            129             129
# 1        AD Russell        2        6              6               6
# 2           RR Pant      252        3              3             252
# 3          CH Gayle      494      134            134             494
# 4         SR Watson      252      129            252             129
# 5        AD Russell        6      494            494               6
# 6         JJ Bumrah        3        1              1               3
# 7       Rashid Khan      134        2            134               2
# 8        MA Agarwal        3      494            494             494
# 9           PP Shaw        6      252            252             252
# 10      JM Bairstow        2        1              1               2
# 11         MS Dhoni      129      134            134             129
# 12        SM Curran      494      252            252             494
# 13          S Gopal        1      134            134             134
# 14        HH Pandya        3      129            129               3
# 15      JM Bairstow      252        2              2               2
# 16       AD Russell        1        6              6               6
# 17  Harbhajan Singh      129      494            129             129
# 18        AS Joseph        3        2              2               3
# 19         K Rabada        1      252            252             252
# 20        HF Gurney      134        6              6               6
# 21         KL Rahul        2      494            494             494
# 22        DL Chahar        6      129            129             129
# 23       KA Pollard      494        3              3               3
# 24         MS Dhoni      134      129            129             129
# 25         S Dhawan        6      252            252             252
# 26       JC Buttler        3      134            134             134
# 27   AB de Villiers      494        1              1               1
# 28      Imran Tahir        6      129            129             129
# 29         KMA Paul      252        2              2             252
# 30       SL Malinga        1        3              3               3
# 31         R Ashwin      494      134            134             494
# 32        DA Warner      129        2            129               2
# 33        HH Pandya        3      252              3               3
# 34          V Kohli        1        6              6               1
# 35        SPD Smith        3      134            134             134
# 36          SS Iyer      494      252            252             252
# 37         KK Ahmed        6        2              2               2
# 38         PA Patel        1      129            129               1
# 39          RR Pant      134      252            252             252
# 40        SR Watson        2      129            129             129
# 41   AB de Villiers        1      494            494               1
# 42         VR Aaron        6      134            134             134
# 43        RG Sharma        3      129            129               3
# 44       JD Unadkat        2      134            134             134
# 45         S Dhawan      252        1            252             252
# 46       AD Russell        6        3              3               6
# 47        DA Warner        2      494            494               2
# 48                         1      134            134             134
# 49         MS Dhoni      129      252            252             129
# 50        JJ Bumrah        3        2              3               2
# 51     Shubman Gill      494        6              6               6
# 52         A Mishra      134      252            134             252
# 53       SO Hetmyer        2        1              1               1
# 54         KL Rahul      129      494            494             494
# 55        HH Pandya        6        3              3               3
# 56         SA Yadav      129        3            129               3
# 57          RR Pant        2      252            252             252
# 58     F du Plessis      252      129            129             129
# 59        JJ Bumrah        3      129              3               3
#
#     player_of_match_id
# 0                228.0
# 1               1437.0
# 2                181.0
# 3                  1.0
# 4                  5.0
# 5               1437.0
# 6                 33.0
# 7                 22.0
# 8                 35.0
# 9               1849.0
# 10              2719.0
# 11                38.0
# 12              2768.0
# 13              1449.0
# 14                30.0
# 15              2719.0
# 16              1437.0
# 17               228.0
# 18              3100.0
# 19               590.0
# 20              3156.0
# 21              1409.0
# 22                41.0
# 23                29.0
# 24                38.0
# 25                13.0
# 26                24.0
# 27               245.0
# 28                44.0
# 29              2745.0
# 30               230.0
# 31              1416.0
# 32                12.0
# 33                30.0
# 34               332.0
# 35                36.0
# 36               389.0
# 37              2662.0
# 38                23.0
# 39               181.0
# 40                 5.0
# 41               245.0
# 42               241.0
# 43                25.0
# 44               438.0
# 45                13.0
# 46              1437.0
# 47                12.0
# 48                 NaN
# 49                38.0
# 50                33.0
# 51              1580.0
# 52               185.0
# 53              2700.0
# 54              1409.0
# 55                30.0
# 56                61.0
# 57               181.0
# 58               267.0
# 59                33.0
#
# [60 rows x 28 columns]

# %%
# Command 7 — WHERE with a numeric condition
q("""
SELECT *
FROM matches
WHERE win_by_runs > 100;
""")

# My observation:
# The greater-than condition returns matches where the winning margin in runs exceeded 100.
# Out:
#     match_id  season_id  balls_per_over           city  match_date  \
# 0     335982       2008               6      Bangalore  2008-04-18
# 1    1082635       2017               6          Delhi  2017-05-06
# 2    1136601       2018               6        Kolkata  2018-05-09
# 3    1175366       2019               6      Hyderabad  2019-03-31
# 4    1359534       2023               6         Jaipur  2023-05-14
# 5    1422134       2024               6  Visakhapatnam  2024-04-03
# 6     336038       2008               6         Mumbai  2008-05-30
# 7     501260       2011               6     Dharamsala  2011-05-17
# 8     598027       2013               6      Bangalore  2013-04-23
# 9     829785       2015               6      Bangalore  2015-05-06
# 10    980987       2016               6      Bangalore  2016-05-14
# 11   1473505       2025               6          Delhi  2025-05-25
# 12   1529276       2026               6         Mumbai  2026-04-23
#
#                event_name  match_number gender match_type format  ...  \
# 0   Indian Premier League           1.0   male        T20    T20  ...
# 1   Indian Premier League          45.0   male        T20    T20  ...
# 2   Indian Premier League          41.0   male        T20    T20  ...
# 3   Indian Premier League          11.0   male        T20    T20  ...
# 4   Indian Premier League          60.0   male        T20    T20  ...
# 5   Indian Premier League          16.0   male        T20    T20  ...
# 6   Indian Premier League           NaN   male        T20    T20  ...
# 7   Indian Premier League          63.0   male        T20    T20  ...
# 8   Indian Premier League          31.0   male        T20    T20  ...
# 9   Indian Premier League          40.0   male        T20    T20  ...
# 10  Indian Premier League          44.0   male        T20    T20  ...
# 11  Indian Premier League          68.0   male        T20    T20  ...
# 12  Indian Premier League          33.0   male        T20    T20  ...
#
#                    match_winner win_by_runs win_by_wickets result  \
# 0         Kolkata Knight Riders       140.0           None    win
# 1                Mumbai Indians       146.0           None    win
# 2                Mumbai Indians       102.0           None    win
# 3           Sunrisers Hyderabad       118.0           None    win
# 4   Royal Challengers Bangalore       112.0           None    win
# 5         Kolkata Knight Riders       106.0           None    win
# 6              Rajasthan Royals       105.0           None    win
# 7                  Punjab Kings       111.0           None    win
# 8   Royal Challengers Bangalore       130.0           None    win
# 9   Royal Challengers Bangalore       138.0           None    win
# 10  Royal Challengers Bangalore       144.0           None    win
# 11          Sunrisers Hyderabad       110.0           None    win
# 12          Chennai Super Kings       103.0           None    win
#
#    player_of_match team1_id team2_id toss_winner_id match_winner_id  \
# 0      BB McCullum        1        6              1               6
# 1      LMP Simmons      252        3            252               3
# 2     Ishan Kishan        3        6              6               3
# 3      JM Bairstow        2        1              1               2
# 4       WD Parnell        1      134              1               1
# 5        SP Narine        6      252              6               6
# 6        SR Watson      252      134            252             134
# 7     AC Gilchrist      494        1            494             494
# 8         CH Gayle        1     1419           1419               1
# 9         CH Gayle        1      494            494               1
# 10  AB de Villiers        1        5              5               1
# 11       H Klaasen        2        6              2               2
# 12       SV Samson      129        3              3             129
#
#     player_of_match_id
# 0                 46.0
# 1               1035.0
# 2                347.0
# 3               2719.0
# 4               8626.0
# 5                 65.0
# 6                  5.0
# 7              12007.0
# 8                  1.0
# 9                  1.0
# 10               245.0
# 11              1740.0
# 12               180.0
#
# [13 rows x 28 columns]

# %%
# Command 8 — Multiple WHERE conditions
q("""
SELECT *
FROM matches
WHERE season = 2016
  AND win_by_wickets > 5;
""")

# My observation:
# AND requires both conditions to be true, so only qualifying 2016 matches are returned.
# Out:
#     match_id  season_id  balls_per_over           city  match_date  \
# 0     980901       2016               6         Mumbai  2016-04-09
# 1     980903       2016               6        Kolkata  2016-04-10
# 2     980909       2016               6        Kolkata  2016-04-13
# 3     980911       2016               6         Rajkot  2016-04-14
# 4     980913       2016               6          Delhi  2016-04-15
# 5     980915       2016               6      Hyderabad  2016-04-16
# 6     980919       2016               6     Chandigarh  2016-04-17
# 7     980921       2016               6      Bangalore  2016-04-17
# 8     980923       2016               6      Hyderabad  2016-04-18
# 9     980925       2016               6     Chandigarh  2016-04-19
# 10    980927       2016               6         Mumbai  2016-04-20
# 11    980929       2016               6         Rajkot  2016-04-21
# 12    980937       2016               6         Rajkot  2016-04-24
# 13    980947       2016               6         Mumbai  2016-04-28
# 14    980957       2016               6           Pune  2016-05-01
# 15    980961       2016               6         Rajkot  2016-05-03
# 16    980965       2016               6          Delhi  2016-05-05
# 17    980969       2016               6      Bangalore  2016-05-07
# 18    980981       2016               6      Bangalore  2016-05-11
# 19    980983       2016               6      Hyderabad  2016-05-12
# 20    980985       2016               6  Visakhapatnam  2016-05-13
# 21    980989       2016               6        Kolkata  2016-05-14
# 22    980991       2016               6     Chandigarh  2016-05-15
# 23    980995       2016               6        Kolkata  2016-05-16
# 24    981001       2016               6         Kanpur  2016-05-19
# 25    981003       2016               6         Raipur  2016-05-20
# 26    981007       2016               6         Kanpur  2016-05-21
# 27    981011       2016               6         Raipur  2016-05-22
#
#                event_name  match_number gender match_type format  ...  \
# 0   Indian Premier League           1.0   male        T20    T20  ...
# 1   Indian Premier League           2.0   male        T20    T20  ...
# 2   Indian Premier League           5.0   male        T20    T20  ...
# 3   Indian Premier League           6.0   male        T20    T20  ...
# 4   Indian Premier League           7.0   male        T20    T20  ...
# 5   Indian Premier League           8.0   male        T20    T20  ...
# 6   Indian Premier League          10.0   male        T20    T20  ...
# 7   Indian Premier League          11.0   male        T20    T20  ...
# 8   Indian Premier League          12.0   male        T20    T20  ...
# 9   Indian Premier League          13.0   male        T20    T20  ...
# 10  Indian Premier League          14.0   male        T20    T20  ...
# 11  Indian Premier League          15.0   male        T20    T20  ...
# 12  Indian Premier League          19.0   male        T20    T20  ...
# 13  Indian Premier League          24.0   male        T20    T20  ...
# 14  Indian Premier League          29.0   male        T20    T20  ...
# 15  Indian Premier League          31.0   male        T20    T20  ...
# 16  Indian Premier League          33.0   male        T20    T20  ...
# 17  Indian Premier League          35.0   male        T20    T20  ...
# 18  Indian Premier League          41.0   male        T20    T20  ...
# 19  Indian Premier League          42.0   male        T20    T20  ...
# 20  Indian Premier League          43.0   male        T20    T20  ...
# 21  Indian Premier League          45.0   male        T20    T20  ...
# 22  Indian Premier League          46.0   male        T20    T20  ...
# 23  Indian Premier League          48.0   male        T20    T20  ...
# 24  Indian Premier League          51.0   male        T20    T20  ...
# 25  Indian Premier League          52.0   male        T20    T20  ...
# 26  Indian Premier League          54.0   male        T20    T20  ...
# 27  Indian Premier League          56.0   male        T20    T20  ...
#
#                    match_winner win_by_runs win_by_wickets result  \
# 0        Rising Pune Supergiant        None            9.0    win
# 1         Kolkata Knight Riders        None            9.0    win
# 2                Mumbai Indians        None            6.0    win
# 3                 Gujarat Lions        None            7.0    win
# 4                Delhi Capitals        None            8.0    win
# 5         Kolkata Knight Riders        None            8.0    win
# 6                  Punjab Kings        None            6.0    win
# 7                Delhi Capitals        None            7.0    win
# 8           Sunrisers Hyderabad        None            7.0    win
# 9         Kolkata Knight Riders        None            6.0    win
# 10               Mumbai Indians        None            6.0    win
# 11          Sunrisers Hyderabad        None           10.0    win
# 12                Gujarat Lions        None            6.0    win
# 13               Mumbai Indians        None            6.0    win
# 14               Mumbai Indians        None            8.0    win
# 15               Delhi Capitals        None            8.0    win
# 16       Rising Pune Supergiant        None            7.0    win
# 17  Royal Challengers Bangalore        None            7.0    win
# 18               Mumbai Indians        None            6.0    win
# 19               Delhi Capitals        None            7.0    win
# 20                 Punjab Kings        None            7.0    win
# 21        Kolkata Knight Riders        None            8.0    win
# 22          Sunrisers Hyderabad        None            7.0    win
# 23  Royal Challengers Bangalore        None            9.0    win
# 24                Gujarat Lions        None            6.0    win
# 25               Delhi Capitals        None            6.0    win
# 26                Gujarat Lions        None            6.0    win
# 27  Royal Challengers Bangalore        None            6.0    win
#
#    player_of_match team1_id team2_id toss_winner_id match_winner_id  \
# 0        AM Rahane        3        4              3               4
# 1       AD Russell        6      252              6               6
# 2        RG Sharma        6        3              3               3
# 3         AJ Finch        5        4              4               5
# 4         A Mishra      252      494            252             252
# 5        G Gambhir        2        6              2               6
# 6          M Vohra      494        4              4             494
# 7        Q de Kock        1      252            252             252
# 8        DA Warner        2        3              2               2
# 9       RV Uthappa      494        6              6               6
# 10       RG Sharma        3        1              3               3
# 11         B Kumar        5        2              2               2
# 12         V Kohli        5        1              1               5
# 13       RG Sharma        3        6              3               3
# 14       RG Sharma        4        3              3               3
# 15         RR Pant        5      252            252             252
# 16       AM Rahane      252        4              4               4
# 17         V Kohli        1        4              1               1
# 18       KH Pandya        1        3              3               3
# 19       CH Morris        2      252            252             252
# 20      MP Stoinis        3      494              3             494
# 21       YK Pathan        6        4              4               6
# 22         HM Amla      494        2            494               2
# 23         V Kohli        6        1              1               1
# 24        DR Smith        5        6              5               5
# 25         KK Nair      252        2            252             252
# 26        SK Raina        5        3              5               5
# 27         V Kohli      252        1              1               1
#
#    player_of_match_id
# 0                34.0
# 1              1437.0
# 2                25.0
# 3                48.0
# 4               185.0
# 5                56.0
# 6                68.0
# 7              1421.0
# 8                12.0
# 9                58.0
# 10               25.0
# 11               20.0
# 12              332.0
# 13               25.0
# 14               25.0
# 15              181.0
# 16               34.0
# 17              332.0
# 18               28.0
# 19              182.0
# 20               73.0
# 21               60.0
# 22               67.0
# 23              332.0
# 24               50.0
# 25              179.0
# 26               47.0
# 27              332.0
#
# [28 rows x 28 columns]

# %%
# Command 9 — ORDER BY
q("""
SELECT match_id, season, team1, team2, match_winner, win_by_runs
FROM matches
WHERE win_by_runs IS NOT NULL
ORDER BY win_by_runs DESC
LIMIT 10;
""")

# My observation:
# ORDER BY DESC sorts the winning margins from largest to smallest.
# Out:
#    match_id season                        team1                        team2  \
# 0   1082635   2017               Delhi Capitals               Mumbai Indians
# 1    980987   2016  Royal Challengers Bangalore                Gujarat Lions
# 2    335982   2008  Royal Challengers Bangalore        Kolkata Knight Riders
# 3    829785   2015  Royal Challengers Bangalore                 Punjab Kings
# 4    598027   2013  Royal Challengers Bangalore                Pune Warriors
# 5   1175366   2019          Sunrisers Hyderabad  Royal Challengers Bangalore
# 6   1359534   2023  Royal Challengers Bangalore             Rajasthan Royals
# 7    501260   2011                 Punjab Kings  Royal Challengers Bangalore
# 8   1473505   2025          Sunrisers Hyderabad        Kolkata Knight Riders
# 9   1422134   2024        Kolkata Knight Riders               Delhi Capitals
#
#                   match_winner  win_by_runs
# 0               Mumbai Indians        146.0
# 1  Royal Challengers Bangalore        144.0
# 2        Kolkata Knight Riders        140.0
# 3  Royal Challengers Bangalore        138.0
# 4  Royal Challengers Bangalore        130.0
# 5          Sunrisers Hyderabad        118.0
# 6  Royal Challengers Bangalore        112.0
# 7                 Punjab Kings        111.0
# 8          Sunrisers Hyderabad        110.0
# 9        Kolkata Knight Riders        106.0

# %%
# Command 10 — ORDER BY with NULL filtering
q("""
SELECT match_id, season, team1, team2, match_winner, win_by_wickets
FROM matches
WHERE win_by_wickets IS NOT NULL
ORDER BY win_by_wickets ASC
LIMIT 10;
""")

# My observation:
# IS NOT NULL removes missing wicket margins, and ASC displays the smallest margins first.
# Out:
#    match_id season                        team1                        team2  \
# 0   1136561   2018               Mumbai Indians          Chennai Super Kings
# 1   1136567   2018               Mumbai Indians          Sunrisers Hyderabad
# 2   1359489   2023  Royal Challengers Bangalore         Lucknow Super Giants
# 3   1473441   2025         Lucknow Super Giants               Delhi Capitals
# 4    829791   2015        Kolkata Knight Riders                 Punjab Kings
# 5   1082640   2017                Gujarat Lions               Delhi Capitals
# 6   1136617   2018          Sunrisers Hyderabad          Chennai Super Kings
# 7   1181766   2019          Sunrisers Hyderabad               Delhi Capitals
# 8   1254058   2021               Mumbai Indians  Royal Challengers Bangalore
# 9   1254098   2021        Kolkata Knight Riders          Chennai Super Kings
#
#                   match_winner  win_by_wickets
# 0          Chennai Super Kings             1.0
# 1          Sunrisers Hyderabad             1.0
# 2         Lucknow Super Giants             1.0
# 3               Delhi Capitals             1.0
# 4        Kolkata Knight Riders             1.0
# 5               Delhi Capitals             2.0
# 6          Chennai Super Kings             2.0
# 7               Delhi Capitals             2.0
# 8  Royal Challengers Bangalore             2.0
# 9          Chennai Super Kings             2.0

# %% [markdown]
# ## Part C — Aggregation

# %%
# Command 11 — COUNT and AS
q("""
SELECT COUNT(*) AS total_matches
FROM matches;
""")

# My observation:
# COUNT(*) counts the number of rows in the matches table, while AS gives the result a clear column name.
# Out:
#    total_matches
# 0           1212

# %%
# Command 12 — COUNT(*)
q("""
SELECT COUNT(*) AS total_deliveries
FROM deliveries;
""")

# My observation:
# COUNT(*) counts the total number of delivery records in the deliveries table.
# Out:
#    total_deliveries
# 0            288226

# %%
# Command 13 — COUNT(DISTINCT)
q("""
SELECT COUNT(DISTINCT venue) AS different_venues
FROM matches;
""")

# My observation:
# COUNT(DISTINCT venue) counts the different venue values recorded in matches.
# Out:
#    different_venues
# 0                59

# %%
# Command 14 — GROUP BY and ORDER BY
q("""
SELECT venue, COUNT(*) AS matches_hosted
FROM matches
GROUP BY venue
ORDER BY matches_hosted DESC;
""")

# My observation:
# GROUP BY creates one group for each venue, and COUNT(*) counts matches in each group.
# Out:
#                                                 venue  matches_hosted
# 0                                        Eden Gardens              77
# 1                                    Wankhede Stadium              73
# 2                               M Chinnaswamy Stadium              65
# 3                                    Feroz Shah Kotla              60
# 4                            Wankhede Stadium, Mumbai              57
# 5           Rajiv Gandhi International Stadium, Uppal              49
# 6                     MA Chidambaram Stadium, Chepauk              48
# 7                              Sawai Mansingh Stadium              47
# 8                 Dubai International Cricket Stadium              46
# 9            MA Chidambaram Stadium, Chepauk, Chennai              38
# 10                   Narendra Modi Stadium, Ahmedabad              37
# 11         Punjab Cricket Association Stadium, Mohali              35
# 12                               Sheikh Zayed Stadium              29
# 13                            Sharjah Cricket Stadium              28
# 14                              Eden Gardens, Kolkata              27
# 15                        Arun Jaitley Stadium, Delhi              27
# 16  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...              26
# 17                   M Chinnaswamy Stadium, Bengaluru              24
# 18  Rajiv Gandhi International Stadium, Uppal, Hyd...              23
# 19            Maharashtra Cricket Association Stadium              22
# 20                 Dr DY Patil Sports Academy, Mumbai              20
# 21                     Sawai Mansingh Stadium, Jaipur              19
# 22                         Dr DY Patil Sports Academy              17
# 23                          Brabourne Stadium, Mumbai              17
# 24                         Subrata Roy Sahara Stadium              16
# 25                 Rajiv Gandhi International Stadium              15
# 26                              M.Chinnaswamy Stadium              15
# 27                                          Kingsmead              15
# 28                               Arun Jaitley Stadium              14
# 29      Maharashtra Cricket Association Stadium, Pune              13
# 30  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              13
# 31                                    SuperSport Park              12
# 32                       Sardar Patel Stadium, Motera              12
# 33  Punjab Cricket Association IS Bindra Stadium, ...              11
# 34             Saurashtra Cricket Association Stadium              10
# 35       Punjab Cricket Association IS Bindra Stadium              10
# 36  Maharaja Yadavindra Singh International Cricke...              10
# 37                                  Brabourne Stadium              10
# 38                             MA Chidambaram Stadium               9
# 39                             Holkar Cricket Stadium               9
# 40       Himachal Pradesh Cricket Association Stadium               9
# 41                   Zayed Cricket Stadium, Abu Dhabi               8
# 42                              New Wanderers Stadium               8
# 43                Barsapara Cricket Stadium, Guwahati               8
# 44                                   St George's Park               7
# 45                                           Newlands               7
# 46                 JSCA International Stadium Complex               7
# 47                                   Barabati Stadium               7
# 48   Shaheed Veer Narayan Singh International Stadium               6
# 49  Himachal Pradesh Cricket Association Stadium, ...               6
# 50  Punjab Cricket Association IS Bindra Stadium, ...               5
# 51                                      Nehru Stadium               5
# 52  Maharaja Yadavindra Singh International Cricke...               5
# 53                                         Green Park               4
# 54  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...               4
# 55       Vidarbha Cricket Association Stadium, Jamtha               3
# 56                              De Beers Diamond Oval               3
# 57                                       Buffalo Park               3
# 58                                    OUTsurance Oval               2

# %%
# Command 15 — GROUP BY winners
q("""
SELECT match_winner, COUNT(*) AS number_of_wins
FROM matches
WHERE match_winner IS NOT NULL
GROUP BY match_winner
ORDER BY number_of_wins DESC;
""")

# My observation:
# GROUP BY creates one group for each match winner and COUNT(*) gives the number of wins.
# Out:
#                    match_winner  number_of_wins
# 0                Mumbai Indians             155
# 1           Chennai Super Kings             146
# 2   Royal Challengers Bangalore             139
# 3         Kolkata Knight Riders             137
# 4           Sunrisers Hyderabad             132
# 5                  Punjab Kings             130
# 6                Delhi Capitals             126
# 7              Rajasthan Royals             125
# 8                Gujarat Titans              42
# 9          Lucknow Super Giants              33
# 10       Rising Pune Supergiant              15
# 11                Pune Warriors              13
# 12                Gujarat Lions              13
# 13         Kochi Tuskers Kerala               6

# %%
# Command 16 — HAVING
q("""
SELECT venue, COUNT(*) AS matches_hosted
FROM matches
GROUP BY venue
HAVING COUNT(*) >= 20
ORDER BY matches_hosted DESC;
""")

# My observation:
# HAVING filters grouped results and keeps only venues that hosted at least 20 matches.
# Out:
#                                                 venue  matches_hosted
# 0                                        Eden Gardens              77
# 1                                    Wankhede Stadium              73
# 2                               M Chinnaswamy Stadium              65
# 3                                    Feroz Shah Kotla              60
# 4                            Wankhede Stadium, Mumbai              57
# 5           Rajiv Gandhi International Stadium, Uppal              49
# 6                     MA Chidambaram Stadium, Chepauk              48
# 7                              Sawai Mansingh Stadium              47
# 8                 Dubai International Cricket Stadium              46
# 9            MA Chidambaram Stadium, Chepauk, Chennai              38
# 10                   Narendra Modi Stadium, Ahmedabad              37
# 11         Punjab Cricket Association Stadium, Mohali              35
# 12                               Sheikh Zayed Stadium              29
# 13                            Sharjah Cricket Stadium              28
# 14                              Eden Gardens, Kolkata              27
# 15                        Arun Jaitley Stadium, Delhi              27
# 16  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...              26
# 17                   M Chinnaswamy Stadium, Bengaluru              24
# 18  Rajiv Gandhi International Stadium, Uppal, Hyd...              23
# 19            Maharashtra Cricket Association Stadium              22
# 20                 Dr DY Patil Sports Academy, Mumbai              20

# %%
# Additional aggregation — Bowlers with more than 2,000 deliveries
q("""
SELECT bowler, COUNT(*) AS deliveries_bowled
FROM deliveries
GROUP BY bowler
HAVING COUNT(*) > 2000
ORDER BY deliveries_bowled DESC;
""")

# My observation:
# GROUP BY counts deliveries for each bowler, and HAVING keeps bowlers with more than 2,000 deliveries.
# Out:
#              bowler  deliveries_bowled
# 0          R Ashwin               4868
# 1           B Kumar               4596
# 2         SP Narine               4586
# 3         RA Jadeja               4261
# 4         YS Chahal               4068
# 5         PP Chawla               3895
# 6         JJ Bumrah               3667
# 7          AR Patel               3542
# 8   Harbhajan Singh               3496
# 9          A Mishra               3444
# 10      Rashid Khan               3440
# 11         DJ Bravo               3296
# 12   Sandeep Sharma               3277
# 13         UT Yadav               3190
# 14       SL Malinga               2974
# 15   Mohammed Shami               2909
# 16         TA Boult               2871
# 17   Mohammed Siraj               2652
# 18          P Kumar               2637
# 19        KH Pandya               2632
# 20         HV Patel               2617
# 21         I Sharma               2546
# 22        MM Sharma               2471
# 23       JD Unadkat               2418
# 24        SN Thakur               2303
# 25         DW Steyn               2282
# 26           Z Khan               2276
# 27    Kuldeep Yadav               2275
# 28         K Rabada               2214
# 29    R Vinay Kumar               2186
# 30        SR Watson               2137
# 31        IK Pathan               2113
# 32         CV Varun               2062
# 33        DL Chahar               2051
# 34   Arshdeep Singh               2020

# %% [markdown]
# ## Part D — NULL and Data Quality

# %%
# Command — IS NULL: matches where city is NULL
q("""
SELECT COUNT(*) AS missing_city_matches
FROM matches
WHERE city IS NULL;
""")

# My observation:
# IS NULL correctly identifies rows where the city value is missing.
# Out:
#    missing_city_matches
# 0                    51

# %%
# Command — IS NULL: matches where match_number is NULL
q("""
SELECT COUNT(*) AS missing_match_number
FROM matches
WHERE match_number IS NULL;
""")

# My observation:
# IS NULL identifies matches where match_number has no value.
# Out:
#    missing_match_number
# 0                    70

# %%
# Command — LOWER, TRIM and LENGTH

q("""
SELECT
    fielders_involved,
    TRIM(fielders_involved) AS trimmed_fielders_involved,
    LOWER(TRIM(fielders_involved)) AS normalized_fielders_involved,
    LENGTH(TRIM(fielders_involved)) AS fielders_involved_length
FROM deliveries
WHERE fielders_involved IS NOT NULL
LIMIT 50;
""")

# My observation:
# TRIM removes surrounding spaces, LOWER converts the text to lowercase,
# and LENGTH shows the number of characters in the trimmed value.
# Out:
#             fielders_involved  trimmed_fielders_involved  \
# 0               ['JH Kallis']              ['JH Kallis']
# 1                 ['P Kumar']                ['P Kumar']
# 2                ['CL White']               ['CL White']
# 3                      [None]                     [None]
# 4                      [None]                     [None]
# 5                ['M Kartik']               ['M Kartik']
# 6              ['RT Ponting']             ['RT Ponting']
# 7                ['M Kartik']               ['M Kartik']
# 8              ['RT Ponting']             ['RT Ponting']
# 9                 ['WP Saha']                ['WP Saha']
# 10  ['AB Agarkar', 'WP Saha']  ['AB Agarkar', 'WP Saha']
# 11                     [None]                     [None]
# 12            ['BB McCullum']            ['BB McCullum']
# 13          ['Mandeep Singh']          ['Mandeep Singh']
# 14            ['Sachin Baby']            ['Sachin Baby']
# 15            ['Sachin Baby']            ['Sachin Baby']
# 16                     [None]                     [None]
# 17                     [None]                     [None]
# 18              ['DA Warner']              ['DA Warner']
# 19            ['BCJ Cutting']            ['BCJ Cutting']
# 20           ['Yuvraj Singh']           ['Yuvraj Singh']
# 21           ['MC Henriques']           ['MC Henriques']
# 22           ['Yuvraj Singh']           ['Yuvraj Singh']
# 23           ['MC Henriques']           ['MC Henriques']
# 24                     [None]                     [None]
# 25              ['DA Warner']              ['DA Warner']
# 26              ['CJ Jordan']              ['CJ Jordan']
# 27                     [None]                     [None]
# 28                     [None]                     [None]
# 29                     [None]                     [None]
# 30                     [None]                     [None]
# 31               ['MS Dhoni']               ['MS Dhoni']
# 32               ['R Bhatia']               ['R Bhatia']
# 33             ['MA Agarwal']             ['MA Agarwal']
# 34   ['MS Dhoni', 'AB Dinda']   ['MS Dhoni', 'AB Dinda']
# 35              ['RG Sharma']              ['RG Sharma']
# 36                 ['N Rana']                 ['N Rana']
# 37             ['TG Southee']             ['TG Southee']
# 38              ['YK Pathan']              ['YK Pathan']
# 39                     [None]                     [None]
# 40               ['SA Yadav']               ['SA Yadav']
# 41               ['SA Yadav']               ['SA Yadav']
# 42                     [None]                     [None]
# 43             ['MP Stoinis']             ['MP Stoinis']
# 44                ['M Vohra']                ['M Vohra']
# 45                     [None]                     [None]
# 46                     [None]                     [None]
# 47             ['GJ Maxwell']             ['GJ Maxwell']
# 48              ['MK Tiwary']              ['MK Tiwary']
# 49                     [None]                     [None]
#
#    normalized_fielders_involved  fielders_involved_length
# 0                 ['jh kallis']                        13
# 1                   ['p kumar']                        11
# 2                  ['cl white']                        12
# 3                        [none]                         6
# 4                        [none]                         6
# 5                  ['m kartik']                        12
# 6                ['rt ponting']                        14
# 7                  ['m kartik']                        12
# 8                ['rt ponting']                        14
# 9                   ['wp saha']                        11
# 10    ['ab agarkar', 'wp saha']                        25
# 11                       [none]                         6
# 12              ['bb mccullum']                        15
# 13            ['mandeep singh']                        17
# 14              ['sachin baby']                        15
# 15              ['sachin baby']                        15
# 16                       [none]                         6
# 17                       [none]                         6
# 18                ['da warner']                        13
# 19              ['bcj cutting']                        15
# 20             ['yuvraj singh']                        16
# 21             ['mc henriques']                        16
# 22             ['yuvraj singh']                        16
# 23             ['mc henriques']                        16
# 24                       [none]                         6
# 25                ['da warner']                        13
# 26                ['cj jordan']                        13
# 27                       [none]                         6
# 28                       [none]                         6
# 29                       [none]                         6
# 30                       [none]                         6
# 31                 ['ms dhoni']                        12
# 32                 ['r bhatia']                        12
# 33               ['ma agarwal']                        14
# 34     ['ms dhoni', 'ab dinda']                        24
# 35                ['rg sharma']                        13
# 36                   ['n rana']                        10
# 37               ['tg southee']                        14
# 38                ['yk pathan']                        13
# 39                       [none]                         6
# 40                 ['sa yadav']                        12
# 41                 ['sa yadav']                        12
# 42                       [none]                         6
# 43               ['mp stoinis']                        14
# 44                  ['m vohra']                        11
# 45                       [none]                         6
# 46                       [none]                         6
# 47               ['gj maxwell']                        14
# 48                ['mk tiwary']                        13
# 49                       [none]                         6

# %% [markdown]
# ### Why `= NULL` is not the correct test
#
# SQL uses three-valued logic for NULL. `NULL` represents a missing or unknown value, so a comparison such as `column = NULL` does not evaluate to TRUE. The correct tests are `IS NULL` and `IS NOT NULL`.

# %% [markdown]
# ## Part E — JOIN and LEFT JOIN

# %%
# Command — JOIN matches and venues
q("""
SELECT
    m.match_id,
    v.venue,
    m.city
FROM matches AS m
JOIN venues AS v
    ON m.venue = v.venue;
""")

# My observation:
# JOIN combines matching records from matches and venues using the venue field.
# Out:
#       match_id                                              venue  \
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591          Rajiv Gandhi International Stadium, Uppal
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1311   1529282                        Arun Jaitley Stadium, Delhi
# 1312   1529283  Maharaja Yadavindra Singh International Cricke...
# 1313   1529284                           Wankhede Stadium, Mumbai
# 1314   1529285                   Narendra Modi Stadium, Ahmedabad
# 1315   1529286                     Sawai Mansingh Stadium, Jaipur
#
#                 city
# 0          Bangalore
# 1          Hyderabad
# 2               Pune
# 3             Rajkot
# 4             Indore
# ...              ...
# 1311           Delhi
# 1312  New Chandigarh
# 1313          Mumbai
# 1314       Ahmedabad
# 1315          Jaipur
#
# [1316 rows x 3 columns]

# %%
# Command — JOIN deliveries and players
q("""
SELECT
    d.batter,
    p.bat_style
FROM deliveries AS d
JOIN players AS p
    ON d.batter = p.player_name
LIMIT 100;
""")

# My observation:
# The JOIN adds player information to delivery records by matching the batter name with the player table.
# Out:
#         batter       bat_style
# 0   MN Samuels  Right hand Bat
# 1   MN Samuels  Right hand Bat
# 2   MN Samuels  Right hand Bat
# 3   MN Samuels  Right hand Bat
# 4   MN Samuels  Right hand Bat
# ..         ...             ...
# 95  MN Samuels  Right hand Bat
# 96  MN Samuels  Right hand Bat
# 97  MN Samuels  Right hand Bat
# 98  MN Samuels  Right hand Bat
# 99  MN Samuels  Right hand Bat
#
# [100 rows x 2 columns]

# %%
# Command — LEFT JOIN + IS NULL: batters missing from players
q("""
SELECT DISTINCT
    d.batter
FROM deliveries AS d
LEFT JOIN players AS p
    ON d.batter = p.player_name
WHERE p.player_name IS NULL
ORDER BY d.batter;
""")

# My observation:
# LEFT JOIN keeps all delivery batters, and IS NULL identifies batters that have no matching player record.
# Out:
# Empty DataFrame
# Columns: [batter]
# Index: []

# %%
# Command — LEFT JOIN + IS NULL: match venues missing from venues
q("""
SELECT DISTINCT
    m.venue
FROM matches AS m
LEFT JOIN venues AS v
    ON m.venue = v.venue
WHERE v.venue IS NULL
ORDER BY m.venue;
""")

# My observation:
# LEFT JOIN keeps all match venues, and IS NULL identifies venues without a matching record in the venues table.
# Out:
# Empty DataFrame
# Columns: [venue]
# Index: []

# %% [markdown]
# ## Part F — CASE WHEN and EXCEPT

# %%
# Command — CASE WHEN: create city_missing
q("""
SELECT
    match_id,
    city,
    CASE
        WHEN city IS NULL THEN 1
        ELSE 0
    END AS city_missing
FROM matches;
""")

# My observation:
# CASE WHEN creates a flag with 1 for missing cities and 0 when a city is present.
# Out:
#       match_id            city  city_missing
# 0       335982       Bangalore             0
# 1      1082591       Hyderabad             0
# 2      1082592            Pune             0
# 3      1082593          Rajkot             0
# 4      1082594          Indore             0
# ...        ...             ...           ...
# 1207   1529282           Delhi             0
# 1208   1529283  New Chandigarh             0
# 1209   1529284          Mumbai             0
# 1210   1529285       Ahmedabad             0
# 1211   1529286          Jaipur             0
#
# [1212 rows x 3 columns]

# %%
# Command — total matches and missing-city matches
q("""
SELECT
    COUNT(*) AS total_matches,
    SUM(
        CASE
            WHEN city IS NULL THEN 1
            ELSE 0
        END
    ) AS missing_city_matches
FROM matches;
""")

# My observation:
# COUNT(*) gives the total matches, while the CASE expression counts matches where city is missing.
# Out:
#    total_matches  missing_city_matches
# 0           1212                    51

# %%
# Command — EXCEPT: venues never appearing in matches
q("""
SELECT venue
FROM venues

EXCEPT

SELECT venue
FROM matches;
""")

# My observation:
# EXCEPT returns venues that exist in the venues table but do not appear in the matches table.
# Out:
# Empty DataFrame
# Columns: [venue]
# Index: []

# %%
# Command — Reverse EXCEPT
q("""
SELECT venue
FROM matches

EXCEPT

SELECT venue
FROM venues;
""")

# My observation:
# Reversing EXCEPT changes the question: it finds venues appearing in matches that are absent from the venues table.
# Out:
# Empty DataFrame
# Columns: [venue]
# Index: []
